# %% [markdown]
# <a href="https://colab.research.google.com/github/AapeliJ/QPA_2_regression_project/blob/main/Project_Combining_datasets_into_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading ESS11 (=> ess11), Corruption Perception Index (=> cpi), and Political Polarization Score (=> pps)
ess11 = pd.read_csv('https://raw.githubusercontent.com/AapeliJ/QPA_2_regression_project/refs/heads/original-datasets/ESS11_reduced_for_QPA.csv')
cpi = pd.read_csv('https://raw.githubusercontent.com/AapeliJ/QPA_2_regression_project/refs/heads/original-datasets/ti-corruption-perception-index/ti-corruption-perception-index.csv')
pps = pd.read_csv('https://raw.githubusercontent.com/AapeliJ/QPA_2_regression_project/refs/heads/original-datasets/political-polarization-score/political-polarization-score.csv')

# %%
ess11.head()
# Out:
#        name cntry   dweight   pspwght   pweight  anweight  trstprl  trstlgl  \
# 0  ESS11e03    AT  1.185115  0.392891  0.330915  0.130013        6        9
# 1  ESS11e03    AT  0.609898  0.325153  0.330915  0.107598        6        6
# 2  ESS11e03    AT  1.392330  4.000023  0.330915  1.323666        7        5
# 3  ESS11e03    AT  0.556061  0.176228  0.330915  0.058316        5        6
# 4  ESS11e03    AT  0.722795  1.060940  0.330915  0.351080        6        8
#
#    stfeco
# 0       6
# 1       2
# 2       6
# 3       4
# 4       6

# %%
cpi.head()
# Out:
#         Entity Code  Year  Corruption Perceptions Index  \
# 0  Afghanistan  AFG  2012                           8.0
# 1  Afghanistan  AFG  2013                           8.0
# 2  Afghanistan  AFG  2014                          12.0
# 3  Afghanistan  AFG  2015                          11.0
# 4  Afghanistan  AFG  2016                          15.0
#
#   World regions according to OWID
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
pps.head()
# Out:
#         Entity Code  Year  Political polarization score (central estimate)
# 0  Afghanistan  AFG  1992                                            2.775
# 1  Afghanistan  AFG  1993                                            2.775
# 2  Afghanistan  AFG  1994                                            2.775
# 3  Afghanistan  AFG  1995                                            2.775
# 4  Afghanistan  AFG  1996                                            2.775

# %%
# EU Member States = Austria, Belgium, Bulgaria, Croatia, Cyprus, Czechia, Denmark, Estonia, Finland, France, Germany, Greece, Hungary,
# Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Netherlands, Poland, Portugal, Romania, Slovakia, Slovenia, Spain, Sweden
# Some of the data has subnational autonomous regions, remove them, only treat nation-by-nation basis, define all the EU countries

eu_countries = [
    "Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia", "Denmark",
    "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Ireland",
    "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands",
    "Poland", "Portugal", "Romania", "Slovakia", "Slovenia", "Spain", "Sweden"]

# %%
print(cpi["Entity"].unique())
# Out:
# ['Afghanistan' 'Aland Islands' 'Albania' 'Algeria' 'American Samoa'
#  'Andorra' 'Angola' 'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia'
#  'Aruba' 'Australia' 'Austria' 'Austria-Hungary' 'Azerbaijan' 'Bahamas'
#  'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin'
#  'Bermuda' 'Bhutan' 'Bolivia' 'Bonaire Sint Eustatius and Saba'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil'
#  'British Indian Ocean Territory' 'British Virgin Islands' 'Brunei'
#  'Bulgaria' 'Burkina Faso' 'Burundi' 'Cambodia' 'Cameroon' 'Canada'
#  'Cape Verde' 'Cayman Islands' 'Central African Republic' 'Chad' 'Chile'
#  'China' 'Christmas Island' 'Cocos Islands' 'Colombia' 'Comoros' 'Congo'
#  'Cook Islands' 'Costa Rica' "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao'
#  'Cyprus' 'Czechia' 'Czechoslovakia' 'Democratic Republic of Congo'
#  'Democratic Republic of Vietnam' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'Duchy of Modena and Reggio'
# ...

# %%
cpi = cpi[cpi["Entity"].isin(eu_countries)]
cpi.head()
# Out:
#       Entity Code  Year  Corruption Perceptions Index  \
# 97   Austria  AUT  2012                          69.0
# 98   Austria  AUT  2013                          69.0
# 99   Austria  AUT  2014                          72.0
# 100  Austria  AUT  2015                          76.0
# 101  Austria  AUT  2016                          75.0
#
#     World regions according to OWID
# 97                              NaN
# 98                              NaN
# 99                              NaN
# 100                             NaN
# 101                             NaN

# %%
print(cpi["Year"].unique())
# Out:
# [2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024]

# %%
print(pps["Year"].unique())
# Out:
# [1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005
#  2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019
#  2020 2021 2022 2023 2024 1900 1901 1902 1903 1904 1905 1906 1907 1908
#  1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919 1920 1921 1922
#  1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933 1934 1935 1936
#  1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947 1948 1949 1950
#  1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961 1962 1963 1964
#  1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978
#  1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991]

# %%
# ESS11 dataproduction in 2024 so lets go with 2024

# %%
pps = pps[pps["Entity"].isin(eu_countries)]
pps.head()
# Out:
#        Entity Code  Year  Political polarization score (central estimate)
# 1248  Austria  AUT  1918                                            2.296
# 1249  Austria  AUT  1919                                            2.296
# 1250  Austria  AUT  1920                                            1.674
# 1251  Austria  AUT  1921                                            1.674
# 1252  Austria  AUT  1922                                            1.674

# %%
cpi = cpi[cpi["Year"] == 2024]
print(cpi["Year"].unique())
# Out:
# [2024]

# %%
cpi.head()
# Out:
#        Entity Code  Year  Corruption Perceptions Index  \
# 109   Austria  AUT  2024                          67.0
# 199   Belgium  BEL  2024                          69.0
# 303  Bulgaria  BGR  2024                          43.0
# 515   Croatia  HRV  2024                          47.0
# 542    Cyprus  CYP  2024                          56.0
#
#     World regions according to OWID
# 109                             NaN
# 199                             NaN
# 303                             NaN
# 515                             NaN
# 542                             NaN

# %%
print(cpi["Entity"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Czechia' 'Denmark'
#  'Estonia' 'Finland' 'France' 'Germany' 'Greece' 'Hungary' 'Ireland'
#  'Italy' 'Latvia' 'Lithuania' 'Luxembourg' 'Malta' 'Netherlands' 'Poland'
#  'Portugal' 'Romania' 'Slovakia' 'Slovenia' 'Spain' 'Sweden']

# %%
pps = pps[pps["Year"] == 2024]
print(pps["Year"].unique())
# Out:
# [2024]

# %%
print(pps["Entity"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Czechia' 'Denmark'
#  'Estonia' 'Finland' 'France' 'Germany' 'Greece' 'Hungary' 'Ireland'
#  'Italy' 'Latvia' 'Lithuania' 'Luxembourg' 'Malta' 'Netherlands' 'Poland'
#  'Portugal' 'Romania' 'Slovakia' 'Slovenia' 'Spain' 'Sweden']

# %%
cpi = cpi.drop(["Code", "World regions according to OWID"], axis=1)
cpi.head()
# Out:
#        Entity  Year  Corruption Perceptions Index
# 109   Austria  2024                          67.0
# 199   Belgium  2024                          69.0
# 303  Bulgaria  2024                          43.0
# 515   Croatia  2024                          47.0
# 542    Cyprus  2024                          56.0

# %%
pps = pps.drop("Code", axis=1)
pps.head()
# Out:
#         Entity  Year  Political polarization score (central estimate)
# 1347   Austria  2024                                           -0.233
# 2097   Belgium  2024                                           -0.340
# 2953  Bulgaria  2024                                            0.462
# 4726   Croatia  2024                                            0.639
# 4974    Cyprus  2024                                            0.545

# %%
# Both CPI and PPS look good, now to remove excess data from ESS and to add the national aggregates to the ESS11 individual scores
# as new columns along the national limits (people from PL get PL aggregate results etc)
# Do I need the weights? idk :) pan, jesli pan to pozniej czyta moze pan moze mi pozniej powiedziec dlaczego te sa wazne

# %%
ess11.head()
# Out:
#        name cntry   dweight   pspwght   pweight  anweight  trstprl  trstlgl  \
# 0  ESS11e03    AT  1.185115  0.392891  0.330915  0.130013        6        9
# 1  ESS11e03    AT  0.609898  0.325153  0.330915  0.107598        6        6
# 2  ESS11e03    AT  1.392330  4.000023  0.330915  1.323666        7        5
# 3  ESS11e03    AT  0.556061  0.176228  0.330915  0.058316        5        6
# 4  ESS11e03    AT  0.722795  1.060940  0.330915  0.351080        6        8
#
#    stfeco
# 0       6
# 1       2
# 2       6
# 3       4
# 4       6

# %%
# idk i'm deleting those weights, maybe i'll regret this later

# %%
ess11 = ess11.drop(["dweight", "pspwght", "pweight", "anweight"], axis=1)
ess11.head()
# Out:
#        name cntry  trstprl  trstlgl  stfeco
# 0  ESS11e03    AT        6        9       6
# 1  ESS11e03    AT        6        6       2
# 2  ESS11e03    AT        7        5       6
# 3  ESS11e03    AT        5        6       4
# 4  ESS11e03    AT        6        8       6

# %%
print(ess11["cntry"].unique())
# Out:
# ['AT' 'BE' 'BG' 'CH' 'CY' 'DE' 'ES' 'FI' 'FR' 'GB' 'GR' 'HR' 'HU' 'IE'
#  'IL' 'IS' 'IT' 'LT' 'LV' 'ME' 'NL' 'NO' 'PL' 'PT' 'RS' 'SE' 'SI' 'SK']

# %%
# Missing the following countries from the EU: Czechia, Denmark, Luxembourg, Romania, habe to change the others to reflect that eventually

# %%
print(pps["Entity"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Czechia' 'Denmark'
#  'Estonia' 'Finland' 'France' 'Germany' 'Greece' 'Hungary' 'Ireland'
#  'Italy' 'Latvia' 'Lithuania' 'Luxembourg' 'Malta' 'Netherlands' 'Poland'
#  'Portugal' 'Romania' 'Slovakia' 'Slovenia' 'Spain' 'Sweden']

# %%
print(cpi["Entity"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Czechia' 'Denmark'
#  'Estonia' 'Finland' 'France' 'Germany' 'Greece' 'Hungary' 'Ireland'
#  'Italy' 'Latvia' 'Lithuania' 'Luxembourg' 'Malta' 'Netherlands' 'Poland'
#  'Portugal' 'Romania' 'Slovakia' 'Slovenia' 'Spain' 'Sweden']

# %%
countries_to_remove = ["Czechia", "Denmark", "Luxembourg", "Romania", "Estonia", "Malta"]

# %%
cpi = cpi[~cpi["Entity"].isin(countries_to_remove)]
print(cpi["Entity"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Finland' 'France'
#  'Germany' 'Greece' 'Hungary' 'Ireland' 'Italy' 'Latvia' 'Lithuania'
#  'Netherlands' 'Poland' 'Portugal' 'Slovakia' 'Slovenia' 'Spain' 'Sweden']

# %%
pps = pps[~pps["Entity"].isin(countries_to_remove)]
print(pps["Entity"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Finland' 'France'
#  'Germany' 'Greece' 'Hungary' 'Ireland' 'Italy' 'Latvia' 'Lithuania'
#  'Netherlands' 'Poland' 'Portugal' 'Slovakia' 'Slovenia' 'Spain' 'Sweden']

# %%
code_to_name = {
    "AT": "Austria",
    "BE": "Belgium",
    "BG": "Bulgaria",
    "CY": "Cyprus",
    "DE": "Germany",
    "ES": "Spain",
    "FI": "Finland",
    "FR": "France",
    "GR": "Greece",
    "HR": "Croatia",
    "HU": "Hungary",
    "IE": "Ireland",
    "IT": "Italy",
    "LT": "Lithuania",
    "LV": "Latvia",
    "NL": "Netherlands",
    "PL": "Poland",
    "PT": "Portugal",
    "SE": "Sweden",
    "SI": "Slovenia",
    "SK": "Slovakia"
}

# %%
ess11["cntry_clean"] = ess11["cntry"].astype(str).str.strip().str.upper()

# %%
ess11["country_name"] = ess11["cntry_clean"].map(code_to_name)

# %%
missing = ess11[ess11["country_name"].isna()]["cntry_clean"].unique()
if len(missing) > 0:
    print("Unmatched country codes:", missing)
# Out:
# Unmatched country codes: ['CH' 'GB' 'IL' 'IS' 'ME' 'NO' 'RS']

# %%
print(ess11[["cntry", "cntry_clean", "country_name"]].head())
# Out:
#   cntry cntry_clean country_name
# 0    AT          AT      Austria
# 1    AT          AT      Austria
# 2    AT          AT      Austria
# 3    AT          AT      Austria
# 4    AT          AT      Austria

# %%
print(ess11["country_name"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' nan 'Cyprus' 'Germany' 'Spain' 'Finland'
#  'France' 'Greece' 'Croatia' 'Hungary' 'Ireland' 'Italy' 'Lithuania'
#  'Latvia' 'Netherlands' 'Poland' 'Portugal' 'Sweden' 'Slovenia' 'Slovakia']

# %%
print(cpi["Entity"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Finland' 'France'
#  'Germany' 'Greece' 'Hungary' 'Ireland' 'Italy' 'Latvia' 'Lithuania'
#  'Netherlands' 'Poland' 'Portugal' 'Slovakia' 'Slovenia' 'Spain' 'Sweden']

# %%
print(pps["Entity"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Finland' 'France'
#  'Germany' 'Greece' 'Hungary' 'Ireland' 'Italy' 'Latvia' 'Lithuania'
#  'Netherlands' 'Poland' 'Portugal' 'Slovakia' 'Slovenia' 'Spain' 'Sweden']

# %%
ess11 = ess11.dropna(subset=["country_name"])
ess11.reset_index(drop=True, inplace=True)
print(ess11["country_name"].unique())
# Out:
# ['Austria' 'Belgium' 'Bulgaria' 'Cyprus' 'Germany' 'Spain' 'Finland'
#  'France' 'Greece' 'Croatia' 'Hungary' 'Ireland' 'Italy' 'Lithuania'
#  'Latvia' 'Netherlands' 'Poland' 'Portugal' 'Sweden' 'Slovenia' 'Slovakia']

# %%
ess11.head()
# Out:
#        name cntry  trstprl  trstlgl  stfeco cntry_clean country_name
# 0  ESS11e03    AT        6        9       6          AT      Austria
# 1  ESS11e03    AT        6        6       2          AT      Austria
# 2  ESS11e03    AT        7        5       6          AT      Austria
# 3  ESS11e03    AT        5        6       4          AT      Austria
# 4  ESS11e03    AT        6        8       6          AT      Austria

# %%
ess11.drop("cntry_clean", axis=1, inplace=True)
ess11.head()
# Out:
# /tmp/ipython-input-1213460282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ess11.drop("cntry_clean", axis=1, inplace=True)
#        name cntry  trstprl  trstlgl  stfeco country_name
# 0  ESS11e03    AT        6        9       6      Austria
# 1  ESS11e03    AT        6        6       2      Austria
# 2  ESS11e03    AT        7        5       6      Austria
# 3  ESS11e03    AT        5        6       4      Austria
# 4  ESS11e03    AT        6        8       6      Austria

# %%
ess11.rename(columns={"country_name": "Entity"}, inplace=True)
print(ess11.columns)
# Out:
# Index(['name', 'cntry', 'trstprl', 'trstlgl', 'stfeco', 'Entity'], dtype='object')
# /tmp/ipython-input-3868145816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ess11.rename(columns={"country_name": "Entity"}, inplace=True)

# %%
ess11 = ess11.merge(
    cpi,
    on="Entity",
    how="left"
)

# %%
ess11 = ess11.merge(
    pps,
    on="Entity",
    how="left"
)

# %%
ess11.head()
# Out:
#        name cntry  trstprl  trstlgl  stfeco   Entity  Year_x  \
# 0  ESS11e03    AT        6        9       6  Austria    2024
# 1  ESS11e03    AT        6        6       2  Austria    2024
# 2  ESS11e03    AT        7        5       6  Austria    2024
# 3  ESS11e03    AT        5        6       4  Austria    2024
# 4  ESS11e03    AT        6        8       6  Austria    2024
#
#    Corruption Perceptions Index  Year_y  \
# 0                          67.0    2024
# 1                          67.0    2024
# 2                          67.0    2024
# 3                          67.0    2024
# 4                          67.0    2024
#
#    Political polarization score (central estimate)
# 0                                           -0.233
# 1                                           -0.233
# 2                                           -0.233
# 3                                           -0.233
# 4                                           -0.233

# %%
ess11.drop("Year_x", axis=1, inplace=True)
ess11.head()
# Out:
#        name cntry  trstprl  trstlgl  stfeco   Entity  \
# 0  ESS11e03    AT        6        9       6  Austria
# 1  ESS11e03    AT        6        6       2  Austria
# 2  ESS11e03    AT        7        5       6  Austria
# 3  ESS11e03    AT        5        6       4  Austria
# 4  ESS11e03    AT        6        8       6  Austria
#
#    Corruption Perceptions Index  Year_y  \
# 0                          67.0    2024
# 1                          67.0    2024
# 2                          67.0    2024
# 3                          67.0    2024
# 4                          67.0    2024
#
#    Political polarization score (central estimate)
# 0                                           -0.233
# 1                                           -0.233
# 2                                           -0.233
# 3                                           -0.233
# 4                                           -0.233

# %%
ess11.drop("Year_y", axis=1, inplace=True)
ess11.head()
# Out:
#        name cntry  trstprl  trstlgl  stfeco   Entity  \
# 0  ESS11e03    AT        6        9       6  Austria
# 1  ESS11e03    AT        6        6       2  Austria
# 2  ESS11e03    AT        7        5       6  Austria
# 3  ESS11e03    AT        5        6       4  Austria
# 4  ESS11e03    AT        6        8       6  Austria
#
#    Corruption Perceptions Index  \
# 0                          67.0
# 1                          67.0
# 2                          67.0
# 3                          67.0
# 4                          67.0
#
#    Political polarization score (central estimate)
# 0                                           -0.233
# 1                                           -0.233
# 2                                           -0.233
# 3                                           -0.233
# 4                                           -0.233

# %%
ess11.rename(columns={"Corruption Perceptions Index": "CPI"}, inplace=True)
ess11.rename(columns={"Political polarization score (central estimate)": "PPS"}, inplace=True)
ess11.head()
# Out:
#        name cntry  trstprl  trstlgl  stfeco   Entity   CPI    PPS
# 0  ESS11e03    AT        6        9       6  Austria  67.0 -0.233
# 1  ESS11e03    AT        6        6       2  Austria  67.0 -0.233
# 2  ESS11e03    AT        7        5       6  Austria  67.0 -0.233
# 3  ESS11e03    AT        5        6       4  Austria  67.0 -0.233
# 4  ESS11e03    AT        6        8       6  Austria  67.0 -0.233

# %%
ess11.to_csv("Project_merged.csv", index=False)
files.download("Project_merged.csv")
